# %%
import sqlite3
from sqlite3 import Error
# Out:
#   File "<ipython-input-3-8d239c31def8>", line 3
#     import React from 'react';
#                     ^
# SyntaxError: invalid syntax

# %%
pip install Django
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 2.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 KB 1.1 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.3.1 is available.
# You should consider upgrading via the '/Users/aleenaalex/opt/anaconda3/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
def create_connection(db_file):
    """ create a database connection to the SQLite database
        specified by the db_file
    :param db_file: database file
    :return: Connection object or None
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn

# %%
def select_all_tasks(conn):
    """
    Query all rows in the tasks table
    :param conn: the Connection object
    :return:
    """
    cur = conn.cursor()
    cur.execute("SELECT hash, message, author_name, author_email, author_when, committer_name, committer_email, committer_when, parents FROM commits;")

    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
def main():
    database = r"commits_libgit2.db"

    # create a database connection
    conn = create_connection(database)
    with conn:
        print("1. Query task by priority:")
        select_task_by_priority(conn, 'Edward Thomson')

        print("2. Query all tasks")
        select_all_tasks(conn)


if __name__ == '__main__':
    main()
# Out:
# 1. Query task by priority:
# ('a3841af5eecc6301e87f8302c7fdce6555e39247', 'benchmark: update path\n\nThe path to the default CLI output has changed, update it.', 'Edward Thomson', 'ethomson@edwardthomson.com', '2022-10-18T13:11:19+01:00', 'GitHub', 'noreply@github.com', '2022-10-18T13:11:19+01:00', 1)
# ('9286e5991ecea7fcdad2f6e68181e30d240ebd98', 'Merge pull request #6405 from libgit2/ethomson/experimental\n\nSupport non-cmake builds with an in-tree `experimental.h`', 'Edward Thomson', 'ethomson@edwardthomson.com', '2022-09-21T15:19:30+01:00', 'GitHub', 'noreply@github.com', '2022-09-21T15:19:30+01:00', 2)
# ('d78fad1519fa8ea85d6a461ac4a394c834da2624', 'Merge pull request #6395 from arroz/fix/nonexistent-worktree-lookup-error-code\n\n#6366: When a worktree is missing, return GIT_ENOTFOUND.', 'Edward Thomson', 'ethomson@edwardthomson.com', '2022-09-19T10:59:58+01:00', 'GitHub', 'noreply@github.com', '2022-09-19T10:59:58+01:00', 2)
# ...

# %%
def select_task_by_priority(conn, author_name):
    """
    Query tasks by priority
    :param conn: the Connection object
    :param priority:
    :return:
    """
    cur = conn.cursor()
    cur.execute("SELECT * FROM commits WHERE author_name=?", (author_name,))

    rows = cur.fetchall()

    for row in rows:
        print(row)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-5d596fc4752c> in <module>
# ----> 1 class MyComponent(Component):
#       2     def __init__(self):
#       3         super().__init__()
#       4
#       5     def render(self):
#
# NameError: name 'Component' is not defined
